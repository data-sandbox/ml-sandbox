# %% [markdown]
# ## Recommendation Engine
#
# The aim of this notebook is to build a movie recommendation engine. We'll use the MovieLens 25M [dataset](https://www.grouplens.org/datasets/movielens/), which contains 25 million ratings. We'll look at two main approaches:
# 1. Content-based rating - generate recommendations based on movie features
# 2. Collaborative rating - generate recommendations based on movie features and similar users' ratings

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re

from sklearn import base
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# We'll start by loading in the movie datasets and exploring the contents.

# %%
df_movies = pd.read_csv(Path('./ml-25m/movies.csv'))
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_ratings = pd.read_csv(Path('./ml-25m/ratings.csv'))
df_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
df_tags = pd.read_csv(Path('./ml-25m/tags.csv'))
df_tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
df_links = pd.read_csv(Path('./ml-25m/links.csv'))
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df_gtags = pd.read_csv(Path('./ml-25m/genome-tags.csv'))
df_gtags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
df_gscores = pd.read_csv(Path('./ml-25m/genome-scores.csv'))
df_gscores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %% [markdown]
# ### Preprocessing
# Starting with the movies dataframe, let's extract the year from the title.

# %%
def get_year(string):
    year = re.findall(r"\(([0-9]{4})\)", string)
    if year:
        return int(year[0])
    else:
        return 0 # returning None coerces the column to float

movies = df_movies.copy()
movies['year'] = df_movies['title'].apply(lambda x: get_year(x))
movies.sort_values('year', ascending=False).head()
# Out:
#        movieId                                          title  \
# 59184   200300                           Triple Threat (2019)
# 58190   198087             Non ci resta che il crimine (2019)
# 60410   203242                   Framing John DeLorean (2019)
# 59710   201452                     A March to Remember (2019)
# 59709   201450  Buñuel in the Labyrinth of the Turtles (2019)
#
#                   genres  year
# 59184    Action|Thriller  2019
# 58190             Comedy  2019
# 60410  Documentary|Drama  2019
# 59710              Drama  2019
# 59709          Animation  2019

# %%
# Earliest movies with valid year listed
movies.query('year > 0').sort_values('year', ascending=True).head()
# Out:
#        movieId                               title              genres  year
# 35536   148054             Passage de Venus (1874)         Documentary  1874
# 35533   148048   Sallie Gardner at a Gallop (1878)  (no genres listed)  1878
# 59938   202045      Athlete Swinging a Pick (1880)         Documentary  1880
# 43771   166800              Buffalo Running (1883)  (no genres listed)  1883
# 35529   148040  Man Walking Around a Corner (1887)  (no genres listed)  1887

# %% [markdown]
# Next we'll convert the genres field from a pipe-separated string into a list so that we can do featuring engineering with it.

# %%
movies['genres'] = df_movies['genres'].apply(lambda x: x.split('|'))
movies.set_index('movieId')
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
# ...                                     ...
# 209157                            We (2018)
# 209159            Window of the Soul (2001)
# 209163                     Bad Poems (2018)
# 209169                  A Girl Thing (2001)
# 209171       Women of Devil's Island (1962)
#
#                                                     genres  year
# movieId
# 1        [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 2                           [Adventure, Children, Fantasy]  1995
# 3                                        [Comedy, Romance]  1995
# 4                                 [Comedy, Drama, Romance]  1995
# 5                                                 [Comedy]  1995
# ...                                                    ...   ...
# 209157                                             [Drama]  2018
# 209159                                       [Documentary]  2001
# 209163                                     [Comedy, Drama]  2018
# 209169                                [(no genres listed)]  2001
# 209171                          [Action, Adventure, Drama]  1962
#
# [62423 rows x 3 columns]

# %% [markdown]
# We'll do the same for tags after grouping by movie.

# %%
tags = df_tags.groupby('movieId')['tag'].apply(lambda x: x.tolist())
tags.head()
# Out:
# movieId
# 1    [Owned, imdb top 250, Pixar, Pixar, time trave...
# 2    [Robin Williams, time travel, fantasy, based o...
# 3    [funny, best friend, duringcreditsstinger, fis...
# 4    [based on novel or book, chick flick, divorce,...
# 5    [aging, baby, confidence, contraception, daugh...
# Name: tag, dtype: object

# %% [markdown]
# And finally let's merge the dataframes.

# %%
combined = movies.merge(tags.to_frame(), on='movieId', how='left')
combined.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres  year  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                     [Adventure, Children, Fantasy]  1995
# 2                                  [Comedy, Romance]  1995
# 3                           [Comedy, Drama, Romance]  1995
# 4                                           [Comedy]  1995
#
#                                                  tag
# 0  [Owned, imdb top 250, Pixar, Pixar, time trave...
# 1  [Robin Williams, time travel, fantasy, based o...
# 2  [funny, best friend, duringcreditsstinger, fis...
# 3  [based on novel or book, chick flick, divorce,...
# 4  [aging, baby, confidence, contraception, daugh...

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62423 entries, 0 to 62422
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  62423 non-null  int64
#  1   title    62423 non-null  object
#  2   genres   62423 non-null  object
#  3   year     62423 non-null  int64
#  4   tag      45251 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 2.9+ MB

# %% [markdown]
# ### Model Development
# We're now ready to start building the recommendation engine. We'll vectorize both genres and tags with one-hot encoding via a custom transformer.

# %%
class DictEncoder(base.BaseEstimator, base.TransformerMixin):
    """Transform list into dictionary with one-hot encoding"""
    def __init__(self, col):
        self.col = col
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        def to_dict(l):
            try:
                return {x: 1 for x in l}
            except TypeError:
                return {}
        
        return X[self.col].apply(to_dict)

# %% [markdown]
# Next let's build the pipeline. We'll use `DictVectorizer()` to transform the list of dictionaries from `DictEncoder()` into columns, where each key gets a column and the value is either 0 or 1.

# %%
genre_pipe = Pipeline([('encode_g', DictEncoder('genres')),
                       ('vectorizer', DictVectorizer())])
genres = genre_pipe.fit_transform(combined)
genres
# Out:
# <62423x20 sparse matrix of type '<class 'numpy.float64'>'
# 	with 112307 stored elements in Compressed Sparse Row format>

# %%
tag_pipe = Pipeline([('encode_t', DictEncoder('tag')),
                     ('vectorizer', DictVectorizer(sort=False))])

union = FeatureUnion([('categories', genre_pipe),
                      ('tags', tag_pipe)])

features = union.fit_transform(combined)
features
# Out:
# <62423x73071 sparse matrix of type '<class 'numpy.float64'>'
# 	with 585169 stored elements in Compressed Sparse Row format>

# %% [markdown]
# The resulting transformation returns 20 unique features from the list of genres, but 73k features from the tags! That's an excessive amount since we don't believe there to be 73k unique concepts encoded in there. Instead, many groups of genres and tags may be representing the same concepts. When using such a large and sparsely populated feature space, its unlikely that similar movies will be near each other based on overlapping genres and tags. To mitigate this problem, we'll add some **dimensionality reduction** to help reduce the sparse space.

# %%
genre_pipe = Pipeline([('encode_g', DictEncoder('genres')),
                       ('vectorizer', DictVectorizer())])

tag_pipe = Pipeline([('encode_t', DictEncoder('tag')),
                     ('vectorizer', DictVectorizer(sort=False)),
                     ('svd', TruncatedSVD(n_components=80))])

union = FeatureUnion([('categories', genre_pipe),
                      ('tags', tag_pipe)])

features = union.fit_transform(combined)
features
# Out:
# <62423x100 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3732387 stored elements in Compressed Sparse Row format>

# %% [markdown]
# There are significantly less features now. This can be further tuned later based on outputs from the recommender.

# %% [markdown]
# ### Nearest Neighbors
# Next let's implement an unsupervised learning algorithm for finding similar movies. `NearestNeighbors` is a simplistic method that looks for the closest neighbors by finding the points where the distance function is minimized.

# %%
nn = NearestNeighbors(n_neighbors=20).fit(features)

# %% [markdown]
# To access how the model is performing, let's spot check some results. We'll start with the movie Toy Story:

# %%
dists, indices = nn.kneighbors(features[0])
combined.iloc[indices[0]]
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 4780      4886                              Monsters, Inc. (2001)
# 8246      8961                            Incredibles, The (2004)
# 1996      2085  101 Dalmatians (One Hundred and One Dalmatians...
# 5110      5218                                     Ice Age (2002)
# 3021      3114                                 Toy Story 2 (1999)
# 6258      6377                                Finding Nemo (2003)
# 3650      3751                                 Chicken Run (2000)
# 2264      2355                               Bug's Life, A (1998)
# 14477    76093                    How to Train Your Dragon (2010)
# 10810    45517                                        Cars (2006)
# 3912      4016                   Emperor's New Groove, The (2000)
# 608        616                             Aristocats, The (1970)
# 580        588                                     Aladdin (1992)
# 2941      3034                                  Robin Hood (1973)
# 1002      1025                     Sword in the Stone, The (1963)
# 11512    52287                          Meet the Robinsons (2007)
# 21068   108932                              The Lego Movie (2014)
# 12939    65261                 Ponyo (Gake no ue no Ponyo) (2008)
# 359        364                              Lion King, The (1994)
#
#                                                   genres  year  \
# 0      [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 4780   [Adventure, Animation, Children, Comedy, Fantasy]  2001
# 8246    [Action, Adventure, Animation, Children, Comedy]  2004
# 1996                    [Adventure, Animation, Children]  1961
# 5110            [Adventure, Animation, Children, Comedy]  2002
# 3021   [Adventure, Animation, Children, Comedy, Fantasy]  1999
# 6258            [Adventure, Animation, Children, Comedy]  2003
# 3650                       [Animation, Children, Comedy]  2000
# 2264            [Adventure, Animation, Children, Comedy]  1998
# 14477    [Adventure, Animation, Children, Fantasy, IMAX]  2010
# 10810                      [Animation, Children, Comedy]  2006
# 3912   [Adventure, Animation, Children, Comedy, Fantasy]  2000
# 608                                [Animation, Children]  1970
# 580    [Adventure, Animation, Children, Comedy, Musical]  1992
# 2941   [Adventure, Animation, Children, Comedy, Musical]  1973
# 1002             [Animation, Children, Fantasy, Musical]  1963
# 11512  [Action, Adventure, Animation, Children, Comed...  2007
# 21068  [Action, Adventure, Animation, Children, Comed...  2014
# 12939          [Adventure, Animation, Children, Fantasy]  2008
# 359    [Adventure, Animation, Children, Drama, Musica...  1994
#
#                                                      tag
# 0      [Owned, imdb top 250, Pixar, Pixar, time trave...
# 4780   [Owned, imdb top 250, Katottava, funny, cute, ...
# 8246   [imdb top 250, Pixar, superhero, animation, co...
# 1996   [60s, children, Disney, animation, dalmatian, ...
# 5110   [Owned, animated, Disney, Katottava, pixar, Ic...
# 3021   [Disney, Owned, imdb top 250, original, animat...
# 6258   [Nice, imdb top 250, short-term memory loss, h...
# 3650   [animation, Dreamworks, Mel Gibson, aardman, a...
# 2264   [Owned, Pixar, Animated, Pixar, animation, ant...
# 14477  [accent, action, adventure, animated, animatio...
# 10810  [animation, Pixar, aftercreditsstinger, anthro...
# 3912   [Animation, breaking the fourth wall, Disney, ...
# 608    [cartoon, Paris, butler, cat, inheritance, mus...
# 580    [Katottava, aftercreditsstinger, animal sideki...
# 2941   [70s, children, animal, animal as human, anima...
# 1002   [60s, children, Disney, king arthur, knight, k...
# 11512  [heartwarming, retrofuture, Disney, inventor, ...
# 21068  [Owned, fun, imagination, breaking the fourth ...
# 12939  [Hayao Miyazaki, lacks tension, 2d animation, ...
# 359    [Disney, animation, Disney, inspirational, car...

# %% [markdown]
# Results look reasonable. A decent mix of genres and Pixar versus other animated films. Let' try another movie.

# %%
# Find movie index for spot check
mask = combined['title'].str.contains('Kill Bill')
combined[mask]
# Out:
#       movieId                     title                     genres  year  \
# 6751     6874  Kill Bill: Vol. 1 (2003)  [Action, Crime, Thriller]  2003
# 7299     7438  Kill Bill: Vol. 2 (2004)  [Action, Drama, Thriller]  2004
#
#                                                     tag
# 6751  [imdb top 250, Tarantino, dark hero, revenge, ...
# 7299  [imdb top 250, Tarantino, Quentin Tarantino, r...

# %%
dists, indices = nn.kneighbors(features[6751])
combined.iloc[indices[0]]
# Out:
#        movieId                                              title  \
# 6751      6874                           Kill Bill: Vol. 1 (2003)
# 7299      7438                           Kill Bill: Vol. 2 (2004)
# 3892      3996  Crouching Tiger, Hidden Dragon (Wo hu cang lon...
#